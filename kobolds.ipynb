# %% [markdown]
# # Kobold names generator
#
# In this notebook we will train a Gaussian Mixture Model to generate
# kobold names. I am a kobold expert and I know what kobold names look
# like, so I will make up the list of example names myself.
#
# For this work, we will need to install the legendary `sklearn` machine
# learning library. My hands literally shiver when I type this.

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.2-cp312-cp312-macosx_10_9_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.19.5 in /Users/scales/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from scikit-learn) (2.1.1)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.14.1-cp312-cp312-macosx_14_0_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 504.6 kB/s eta 0:00:00a 0:00:01
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.5.2-cp312-cp312-macosx_10_9_x86_64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 9.4 MB/s eta 0:00:0000:0100:01
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 7.0 MB/s eta 0:00:0000:01
# Downloading scipy-1.14.1-cp312-cp312-macosx_14_0_x86_64.whl (25.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.6/25.6 MB 10.2 MB/s eta 0:00:0000:0100:01
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.5.2 scipy-1.14.1 threadpoolctl-3.5.0
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## What kobold names are like?
#
# Obviously, kobold names look something like this. If you've ever seen
# a kobold's name, you will immediately know what I mean.

# %%
example_names = [
    'Kobbo', 'Alexandro', 'Raiko', 'Zabu',
    'Marvin', 'Ramuso', 'Meepe', 'Blah'
]

example_names
# Out:
# ['Kobbo', 'Alexandro', 'Raiko', 'Zabu', 'Marvin', 'Ramuso', 'Meepe', 'Blah']

# %% [markdown]
# These are good, gender-neutral names, very fitting for our task.
#
# ## Training
#
# Let's now setup the machine learning model.

# %%
from sklearn.feature_extraction.text import CountVectorizer
from scipy.sparse import csr_matrix
import numpy as np

# Step 1: Feature Extraction using character n-grams
vectorizer = CountVectorizer(analyzer='char', ngram_range=(2, 4))
X: csr_matrix = vectorizer.fit_transform(example_names)

X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 84 stored elements and shape (8, 82)>

# %% [markdown]
# But what is Compressed Sparse Row sparse matrix of dtype 'int64'?

# %%
type(X)
# Out:
# scipy.sparse._csr.csr_matrix

# %% [markdown]
# It's a [Compressed Sparse Row matrix](https://docs.scipy.org/doc/scipy/reference/generated/scipy.sparse.csr_matrix.html),
# a data type from SciPy — a space-efficient representation of a matrix.

# %%
for x in X:
    print(x)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 9 stored elements and shape (1, 82)>
#   Coords	Values
#   (0, 38)	1
#   (0, 58)	1
#   (0, 18)	1
#   (0, 23)	1
#   (0, 39)	1
#   (0, 59)	1
#   (0, 19)	1
#   (0, 40)	1
#   (0, 60)	1
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 21 stored elements and shape (1, 82)>
#   Coords	Values
#   (0, 6)	1
#   (0, 43)	1
#   (0, 32)	1
#   (0, 76)	1
#   (0, 12)	1
#   (0, 55)	1
#   (0, 25)	1
#   (0, 67)	1
#   (0, 7)	1
#   (0, 44)	1
#   (0, 33)	1
#   (0, 77)	1
#   (0, 13)	1
#   (0, 56)	1
#   (0, 26)	1
#   (0, 8)	1
#   (0, 45)	1
#   (0, 34)	1
#   (0, 78)	1
#   (0, 14)	1
#   (0, 57)	1
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 9 stored elements and shape (1, 82)>
#   Coords	Values
#   (0, 38)	1
#   (0, 62)	1
#   (0, 3)	1
#   (0, 35)	1
#   (0, 63)	1
#   (0, 4)	1
#   (0, 36)	1
#   (0, 64)	1
#   (0, 5)	1
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 6 stored elements and shape (1, 82)>
#   Coords	Values
#   (0, 79)	1
#   (0, 0)	1
#   (0, 24)	1
#   (0, 80)	1
#   (0, 1)	1
#   (0, 81)	1
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 12 stored elements and shape (1, 82)>
#   Coords	Values
#   (0, 46)	1
#   (0, 15)	1
#   (0, 68)	1
#   (0, 74)	1
#   (0, 37)	1
#   (0, 47)	1
#   (0, 16)	1
#   (0, 69)	1
#   (0, 75)	1
#   (0, 48)	1
#   (0, 17)	1
#   (0, 70)	1
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 12 stored elements and shape (1, 82)>
#   Coords	Values
#   (0, 62)	1
#   (0, 9)	1
#   (0, 52)	1
#   (0, 72)	1
#   (0, 71)	1
#   (0, 65)	1
#   (0, 10)	1
#   (0, 53)	1
#   (0, 73)	1
#   (0, 66)	1
#   (0, 11)	1
#   (0, 54)	1
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 9 stored elements and shape (1, 82)>
#   Coords	Values
#   (0, 49)	1
#   (0, 27)	1
#   (0, 30)	1
#   (0, 61)	1
#   (0, 50)	1
#   (0, 28)	1
#   (0, 31)	1
#   (0, 51)	1
#   (0, 29)	1
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 6 stored elements and shape (1, 82)>
#   Coords	Values
#   (0, 20)	1
#   (0, 41)	1
#   (0, 2)	1
#   (0, 21)	1
#   (0, 42)	1
#   (0, 22)	1

# %% [markdown]
# Most of the matrix is filled with zeroes, and only in some places
# there are ones.

# %%
from sklearn.mixture import GaussianMixture

# Step 2: Train a Gaussian Mixture Model
gmm = GaussianMixture(n_components=6, random_state=42)
gmm.fit(X.toarray())
# Out:
# GaussianMixture(n_components=6, random_state=42)

# %% [markdown]
# > ***But what is Gaussian Mixture and why do I need it?!***
# >
# > For now I have no idea..
#
# Ahem, anyway, let's now perform the *inference* of our model.

# %%
sample = gmm.sample(10)

sample
# Out:
# (array([[ 5.97720467e-04,  2.55948803e-03, -7.03343802e-04,
#           1.00213962e+00,  1.00049018e+00,  1.00139488e+00,
#           5.97548420e-04, -5.04414161e-04,  5.85878710e-04,
#          -7.67321415e-04, -1.07812384e-03,  5.23438719e-04,
#          -1.05118623e-04,  3.77562060e-04, -1.52161283e-03,
#          -1.22280128e-03,  2.48549341e-04,  2.30587683e-04,
#          -1.62207656e-04, -1.56466897e-03, -2.38136181e-03,
#           5.37754949e-04,  4.68540672e-04,  1.76736024e-04,
#          -6.52266361e-01, -6.52639803e-01, -4.40922976e-04,
#          -2.74095484e-03, -2.43384808e-03, -6.52984957e-01,
#          -6.52060214e-01, -1.77024319e-03, -1.03262907e-03,
#           1.69729284e-04,  8.93939191e-05,  4.88044079e-04,
#           1.58013410e-03],
#         [-1.12541901e-03,  9.73557448e-04,  1.38590332e-03,
#           1.00860295e-03, -1.63221808e-03,  2.80964321e-04,
#           1.00105839e+00,  1.00055208e+00,  9.98833767e-01,
#          -1.18298484e-03,  5.50703793e-04,  1.16114093e-03,
#           1.00017862e+00,  1.00252932e+00,  9.99988431e-01,
#           1.14976179e-03, -5.43122693e-04, -6.62350629e-06,
#          -1.28779697e-03,  3.96378298e-04, -2.19757779e-04,
#          -4.14705517e-04,  4.47692134e-04,  2.24592201e-04,
#          -6.05801025e-04,  1.00103724e+00,  1.00054580e+00,
#           8.60641970e-04,  7.67242351e-04,  7.23303696e-04,
#          -1.52973313e-03, -5.82391769e-04,  9.99652644e-01,
#           9.99151337e-01,  1.00086846e+00,  4.21499323e-04,
#          -5.20191226e-04, -1.38713090e-03,  7.76206831e-04,
#           1.15556289e-04,  1.78404491e-03, -1.78851681e-03,
#          -9.20068808e-04,  9.99530257e-01,  9.99533918e-01,
#           1.00014117e+00,  4.00064875e-04,  4.09112983e-04,
#           1.32180514e-03,  1.75331967e-03,  4.21280078e-04,
#           1.20102875e-03, -1.72297353e-03, -2.35809970e-04,
#           1.99410329e-03,  1.00199611e+00,  1.00041056e+00,
#           1.00020845e+00, -1.45785400e-03,  1.97775571e-03,
#          -1.86366433e-03, -1.32102199e-03, -8.04124698e-04,
#          -7.21481202e-04,  1.73869037e-03, -1.02364710e-03,
#           2.95385868e-04,  1.00018863e+00, -5.04294736e-04,
#          -4.67145853e-04,  1.06784274e-03, -1.05741195e-03,
#          -2.07388002e-03,  9.66996189e-04,  2.48399161e-04,
#           1.19732532e-03,  9.99656212e-01,  9.99561979e-01,
#           9.97906518e-01, -1.49036667e-04, -6.65345463e-06,
#          -1.31914505e-03],
#         [-1.05325872e-03,  4.85315997e-04, -7.72667142e-04,
#          -8.92211756e-05,  2.99836345e-05, -7.04470103e-04,
#          -7.28315150e-04,  9.87457776e-05, -1.30345146e-04,
#           9.99499522e-01,  9.98832659e-01,  9.99898684e-01,
#           9.88130797e-05,  4.11755392e-04,  6.07365739e-05,
#          -1.86181584e-03, -1.28699891e-03,  2.19581352e-04,
#          -1.23281556e-04,  4.01957709e-04, -1.76762534e-04,
#          -1.14995577e-03,  1.11756595e-03,  1.71808865e-03,
#          -1.23282580e-03, -9.91082405e-04, -9.49246850e-04,
#           1.79305029e-03, -9.23386671e-04, -1.01969498e-03,
#           3.30889568e-04,  5.08324081e-05, -1.63174725e-03,
#          -4.29052500e-04, -7.63716681e-04, -1.04772787e-03,
#           1.20454750e-03,  6.52287551e-05, -7.17016527e-04,
#          -1.03797902e-03,  2.27984585e-03, -8.20235526e-04,
#           1.05462995e-03,  6.73783658e-05, -2.74905759e-03,
#          -3.70215807e-04,  2.02830298e-04,  7.79941833e-04,
#           3.51569523e-04, -5.26070322e-04,  2.42560603e-03,
#          -2.22287077e-03,  9.98164166e-01,  1.00187377e+00,
#           9.99988068e-01, -1.64212277e-03,  6.29489667e-04,
#           3.44357269e-04, -1.63703845e-03, -3.61330965e-05,
#           3.41910286e-04,  1.20162061e-03,  9.99311502e-01,
#           7.28611228e-04,  7.56009798e-06,  9.99827629e-01,
#           1.00006663e+00, -6.92000637e-04, -9.53436756e-04,
#          -8.41933868e-04, -4.97179676e-04,  1.00184453e+00,
#           1.00079487e+00,  9.99063109e-01,  5.51863655e-04,
#           2.00557405e-03,  7.17591580e-04, -4.69147720e-04,
#           5.26937413e-04,  1.62053345e-03,  1.57049464e-03,
#          -1.00375789e-03],
#         [-1.31934789e-03, -2.26245219e-04,  1.06456868e-03,
#           1.19605669e-04,  8.16698518e-04,  6.18661960e-04,
#           1.28626861e-03,  1.06220985e-03,  1.79845419e-04,
#          -3.34852272e-04,  1.97502735e-03, -4.72646526e-05,
#          -1.55795232e-03, -4.00381360e-04,  4.99737620e-04,
#           5.32595109e-04, -1.08778094e-03,  9.29482507e-04,
#           1.00176287e+00,  9.97731304e-01,  2.08295067e-04,
#           7.06598954e-04,  2.37608497e-04,  9.99900608e-01,
#           2.41960858e-03,  1.25951751e-03, -2.58425079e-05,
#          -3.17692604e-04, -4.59662838e-05,  2.56518819e-04,
#          -2.48287682e-05, -1.31236893e-03, -6.59549500e-04,
#           3.25207015e-04,  5.91779518e-04,  9.93197206e-04,
#           2.12709127e-04, -1.74560682e-03,  9.99561742e-01,
#           1.00108809e+00,  1.00020186e+00, -6.97659338e-05,
#          -6.41924396e-04,  7.24892389e-04, -9.50697218e-04,
#           8.44494368e-04, -4.62177830e-04,  7.80060894e-04,
#           6.83125357e-04, -1.26096381e-03,  7.54856999e-04,
#          -3.72378247e-04, -1.56357384e-03, -6.83758896e-04,
#           2.52310731e-03,  3.54595483e-04,  7.15994035e-05,
#           4.56348275e-04,  9.99427971e-01,  9.99515974e-01,
#           1.00177191e+00,  7.13399590e-04,  4.70172131e-05,
#           1.22317095e-03, -6.83431790e-04, -5.09857577e-04,
#          -2.48461158e-03,  9.19827510e-04,  3.13861963e-04,
#          -1.68182033e-03, -1.75859900e-03, -8.72630627e-04,
#           7.93657942e-04, -3.00360488e-04, -8.04786917e-04,
#          -1.00611589e-03, -1.05091196e-03, -1.93367830e-03,
#          -1.20739583e-03, -1.07057808e-03,  6.82623236e-04,
#          -1.65723053e-04]]),
#  array([0, 1, 1, 1, 1, 1, 1, 2, 3, 4]))

# %% [markdown]
# I have no idea what this means. :c

# %% [markdown]
# ## Conclusion
#
# I haven't learned anything. I lack some background knowledge I believe.
