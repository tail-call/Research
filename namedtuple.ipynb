# %% [markdown]
# # Tuple of a Healthy Person
#
# https://habr.com/ru/articles/438162/

# %%
from collections import namedtuple

Pony = namedtuple('Pony', 'name hooves horns wings')
twilight = Pony(name='Twilight Sparkle', hooves=4, horns=1, wings=0)

twilight
# Out:
# Pony(name='Twilight Sparkle', hooves=4, horns=1, wings=0)

# %%
twilight.hooves
# Out:
# 4

# %%
twilight[0]
# Out:
# 'Twilight Sparkle'

# %%
def become_princess(pony: Pony):
    if pony.horns == 0:
        # ._replace is non-mutating!!
        pony = pony._replace(horns=1)

    if pony.wings == 0:
        pony = pony._replace(wings=2)

    return pony

become_princess(twilight)._asdict()
# Out:
# {'name': 'Twilight Sparkle', 'hooves': 4, 'horns': 1, 'wings': 2}

# %% [markdown]
# ## `namedtuple` breaks on keywords
#
# This is very sad:

# %%
KeywordCount = namedtuple(
    "KeywordCount",
    "if then else with around whoops sorry def @dataclass"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 KeywordCount = namedtuple(
#       2     "KeywordCount",
#       3     "if then else with around whoops sorry def @dataclass"
#       4 )
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/collections/__init__.py:403, in namedtuple(typename, field_names, rename, defaults, module)
#     400         raise ValueError('Type names and field names must be valid '
#     401                          f'identifiers: {name!r}')
#     402     if _iskeyword(name):
# --> 403         raise ValueError('Type names and field names cannot be a '
#     404                          f'keyword: {name!r}')
#     406 seen = set()
#     407 for name in field_names:
#
# ValueError: Type names and field names cannot be a keyword: 'if'

# %% [markdown]
# But there's a solution: `rename=True`! Just look at this:

# %%
KeywordCount = namedtuple(
    "KeywordCount",
    "if then else with around whoops sorry def @dataclass",
    rename=True
)

KeywordCount._fields
# Out:
# ('_0', 'then', '_2', '_3', 'around', 'whoops', 'sorry', '_7', '_8')

# %% [markdown]
# This is almost funny.
